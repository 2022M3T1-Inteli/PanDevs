# %% [markdown]
# <a href="https://colab.research.google.com/github/2022M3T1/Projeto4/blob/main/notebooks/estudo_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup dos dados iniciais
# ### Instalação de bibliotecas e imports

# %%
# !pip install -U -q PyDrive

# %%
import pandas as pd
import plotly.express as px
from sklearn.preprocessing import LabelBinarizer
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import warnings
warnings.filterwarnings('ignore')
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif, mutual_info_classif

# %% [markdown]
# ### Autenticação para acesso aos dados

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ### Download dos dados para esta máquina virtual

# %%
downloaded = drive.CreateFile({'id': '1EOUJ4FlZ7qeykwLHbth0YgcSfQudLRid'})
downloaded.GetContentFile('data.csv')

# %% [markdown]
# ### Carregando os dados baixados no dataframe

# %%
# Dados lidos do arquvio csv
df = pd.read_csv('data.csv')

# Definição de dataframe que será utilizado na seção de mapeamento de jornada do usuário
new_df = df.copy()

# Filtrando a base de dados com um único mês
last_month = df.anomes == 202204
df = df[last_month]

# Mostrando primeiros registros do Dataframe
df.head()
# Out:
#           anomes                                       num_cpf_hash  \
# 11171813  202204  ffffd54b45ec46113523184fc07185a0d5cbfa876a07ba...
# 11171814  202204  ffffd47a92b3e4291c013033ae528708a19eaede50f78e...
# 11171815  202204  ffffbd4a3d42a12e07b1202d68c33d43220c42c8a55160...
# 11171816  202204  ffffafb315cf6852f08137c4486cc5d52df62c75da4aeb...
# 11171817  202204  ffff73562c0d8d596f2f282af4080212bdb8d5067362cb...
#
#           vlr_credito  vlr_saldo  num_atend_atrs  vlr_score  num_produtos  \
# 11171813     37071.44    8241.16             NaN      523.0           2.0
# 11171814         0.00        NaN             NaN      523.0           4.0
# 11171815      2723.43    1399.99             NaN      780.0           2.0
# 11171816     16411.68        NaN             NaN      415.0           1.0
# 11171817          NaN        NaN             NaN      297.0           NaN
#
#           num_atend  qtd_oper  qtd_reclm  qtd_restr vlr_renda cod_rating  \
# 11171813        NaN      13.0        NaN        1.0       NaN          A
# 11171814        NaN      18.0        NaN        1.0       NaN        NaN
# 11171815        NaN      40.0        NaN        NaN       NaN          A
# 11171816        NaN      10.0        NaN        3.0       NaN        NaN
# 11171817        NaN       NaN        NaN        8.0       NaN        NaN
#
#           ind_atrito  ind_engaj  ind_novo_cli
# 11171813         NaN        1.0           NaN
# 11171814         NaN        NaN           1.0
# 11171815         NaN        1.0           NaN
# 11171816         NaN        NaN           NaN
# 11171817         NaN        NaN           NaN

# %%
df.describe(include="object")
# Out:
#                                              num_cpf_hash vlr_renda cod_rating
# count                                              860680         0     444768
# unique                                             860680         0         10
# top     ffffd54b45ec46113523184fc07185a0d5cbfa876a07ba...       NaN          A
# freq                                                    1       NaN     331447

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860680 entries, 11171813 to 12032492
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   anomes          860680 non-null  int64
#  1   num_cpf_hash    860680 non-null  object
#  2   vlr_credito     468603 non-null  float64
#  3   vlr_saldo       444768 non-null  float64
#  4   num_atend_atrs  521 non-null     float64
#  5   vlr_score       851123 non-null  float64
#  6   num_produtos    477651 non-null  float64
#  7   num_atend       1551 non-null    float64
#  8   qtd_oper        468603 non-null  float64
#  9   qtd_reclm       57 non-null      float64
#  10  qtd_restr       604604 non-null  float64
#  11  vlr_renda       0 non-null       object
#  12  cod_rating      444768 non-null  object
#  13  ind_atrito      216 non-null     float64
#  14  ind_engaj       148236 non-null  float64
#  15  ind_novo_cli    170899 non-null  float64
# dtypes: float64(12), int64(1), object(3)
# memory usage: 111.6+ MB

# %% [markdown]
# ### Removendo colunas que não iremos utilizar

# %%
df = df.drop('vlr_renda', axis=1)

# %% [markdown]
# # Manipulação dos dados das colunas da base de dados geral
# ##### Preenchemos os valores vazios das colunas e tratamos dados que estavam com a tipagem errada.

# %% [markdown]
# Nas seguinte células, transformamos os valores NaN das colunas em 0

# %%
df['ind_atrito'] = df['ind_atrito'].fillna(0)

# %%
df['ind_engaj'] = df['ind_engaj'].fillna(0)

# %%
df['ind_novo_cli'] = df['ind_novo_cli'].fillna(0)

# %%
df['num_atend'] = df['num_atend'].fillna(0)

# %%
df['num_atend_atrs'] = df['num_atend_atrs'].fillna(0)

# %%
df['qtd_reclm'] = df['qtd_reclm'].fillna(0)

# %% [markdown]
# # Divisão da tabela entre clientes e não clientes

# %%
client = df[df.cod_rating.notna()]
not_client = df[df.cod_rating.isna()]

# %%
not_client.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 415912 entries, 11171814 to 12032492
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   anomes          415912 non-null  int64
#  1   num_cpf_hash    415912 non-null  object
#  2   vlr_credito     79788 non-null   float64
#  3   vlr_saldo       0 non-null       float64
#  4   num_atend_atrs  415912 non-null  float64
#  5   vlr_score       415700 non-null  float64
#  6   num_produtos    74984 non-null   float64
#  7   num_atend       415912 non-null  float64
#  8   qtd_oper        79788 non-null   float64
#  9   qtd_reclm       415912 non-null  float64
#  10  qtd_restr       394410 non-null  float64
#  11  cod_rating      0 non-null       object
#  12  ind_atrito      415912 non-null  float64
#  13  ind_engaj       415912 non-null  float64
#  14  ind_novo_cli    415912 non-null  float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 50.8+ MB

# %% [markdown]
# #Visualização gráfica de hipóteses

# %% [markdown]
# ##Hipótese 1
# Clientes com o score mais alto possuem um valor de saldo no banco pan maior (Hipótese não comprovada).

# %%
fig = px.scatter(client.sample(10000), x = "vlr_score", y = "vlr_saldo")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a10c0820-cfda-4c2e-99ee-e7523454e545" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a10c0820-cfda-4c2e-99ee-e7523454e545")) {                    Plotly.newPlot(                        "a10c0820-cfda-4c2e-99ee-e7523454e545",                        [{"hovertemplate":"vlr_score=%{x}<br>vlr_saldo=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[353.0,389.0,488.0,554.0,830.0,135.0,534.0,404.0,575.0,523.0,575.0,null,388.0,572.0,270.0,420.0,921.0,443.0,853.0,884.0,512.0,568.0,188.0,552.0,695.0,460.0,533.0,360.0,411.0,434.0,575.0,295.0,689.0,365.0,653.0,440.0,null,939.0,127.0,928.0,956.0,850.0,440.0,320.0,443.0,153.0,536.0,575.0,415.0,407.0,428.0,477.0,389.0,386.0,525.0,450.0,406.0,null,270.0,506.0,426.0,857.0,590.0,672.0,230.0,621.0,792.0,674.0,417.0,921.0,940.0,575.0,343.0,313.0,375.0,494.0,248.0,293.0,289.0,376.0,517.0,416.0,866.0,366.0,575.0,534.0,678.0,483.0,607.0,416.0,956.0,460.0,873.0,426.0,98.0,361.0,574.0,758.0,426.0,575.0,386.0,420.0,682.0,952.0,0.0,635.0,575.0,576.0,221.0,810.0,912.0,386.0,703.0,659.0,404.0,475.0,302.0,424.0,456.0,460.0,840.0,442.0,186.0,224.0,659.0,425.0,183.0,695.0,353.0,689.0,850.0,443.0,843.0,433.0,397.0,429.0,542.0,500.0,242.0,657.0,452.0,853.0,278.0,348.0,588.0,456.0,156.0,142.0,416.0,546.0,88.0,670.0,412.0,475.0,289.0,360.0,380.0,362.0,396.0,289.0,377.0,null,322.0,149.0,624.0,206.0,956.0,689.0,674.0,325.0,332.0,361.0,951.0,833.0,246.0,641.0,697.0,620.0,359.0,327.0,517.0,434.0,906.0,763.0,895.0,350.0,907.0,712.0,448.0,285.0,575.0,233.0,313.0,512.0,575.0,null,394.0,230.0,575.0,697.0,376.0,400.0,632.0,959.0,622.0,285.0,575.0,846.0,289.0,575.0,410.0,525.0,645.0,850.0,394.0,316.0,682.0,562.0,481.0,486.0,403.0,534.0,356.0,370.0,206.0,687.0,712.0,823.0,871.0,null,707.0,248.0,426.0,467.0,820.0,552.0,933.0,136.0,158.0,575.0,425.0,202.0,389.0,622.0,533.0,460.0,850.0,143.0,622.0,972.0,596.0,736.0,180.0,320.0,665.0,907.0,575.0,120.0,590.0,724.0,421.0,413.0,674.0,107.0,430.0,118.0,111.0,388.0,678.0,575.0,516.0,415.0,276.0,657.0,295.0,950.0,242.0,575.0,437.0,862.0,366.0,null,385.0,219.0,370.0,850.0,0.0,575.0,460.0,421.0,488.0,360.0,382.0,425.0,435.0,322.0,912.0,521.0,237.0,136.0,484.0,859.0,138.0,521.0,575.0,954.0,380.0,836.0,311.0,127.0,406.0,285.0,433.0,726.0,853.0,407.0,412.0,955.0,814.0,374.0,575.0,376.0,959.0,674.0,421.0,590.0,348.0,508.0,950.0,462.0,780.0,329.0,780.0,592.0,90.0,426.0,null,439.0,768.0,588.0,603.0,661.0,632.0,469.0,460.0,780.0,773.0,643.0,440.0,940.0,448.0,552.0,877.0,575.0,344.0,930.0,464.0,575.0,94.0,562.0,443.0,170.0,508.0,366.0,280.0,575.0,868.0,915.0,859.0,961.0,592.0,397.0,null,584.0,369.0,346.0,641.0,327.0,626.0,268.0,129.0,628.0,439.0,871.0,371.0,295.0,475.0,442.0,519.0,542.0,413.0,592.0,302.0,500.0,162.0,458.0,717.0,523.0,866.0,740.0,384.0,355.0,389.0,382.0,542.0,407.0,272.0,120.0,456.0,396.0,306.0,null,322.0,389.0,517.0,548.0,592.0,417.0,740.0,339.0,540.0,374.0,387.0,850.0,575.0,87.0,261.0,130.0,618.0,674.0,361.0,428.0,350.0,533.0,406.0,287.0,568.0,576.0,859.0,710.0,653.0,100.0,395.0,682.0,575.0,316.0,484.0,665.0,422.0,643.0,879.0,278.0,475.0,575.0,722.0,787.0,230.0,548.0,446.0,90.0,790.0,638.0,508.0,456.0,498.0,323.0,366.0,800.0,194.0,655.0,398.0,113.0,354.0,276.0,270.0,935.0,425.0,0.0,200.0,886.0,308.0,722.0,678.0,479.0,342.0,620.0,445.0,387.0,348.0,426.0,477.0,708.0,592.0,655.0,406.0,306.0,951.0,454.0,228.0,397.0,398.0,800.0,504.0,270.0,958.0,316.0,840.0,853.0,442.0,566.0,395.0,719.0,322.0,456.0,689.0,498.0,486.0,542.0,575.0,560.0,753.0,486.0,322.0,458.0,366.0,575.0,387.0,null,814.0,954.0,402.0,462.0,389.0,394.0,763.0,107.0,590.0,920.0,575.0,519.0,750.0,426.0,null,884.0,508.0,517.0,598.0,439.0,546.0,8 ...

# %% [markdown]
# ##Hipótese 2
# O banco pan possui mais clientes com classificação A do que H (Comprovada).

# %%
client.cod_rating.describe()
# Out:
# count     444768
# unique        10
# top            A
# freq      331447
# Name: cod_rating, dtype: object

# %% [markdown]
# ##Hipótese 3
# Como o banco atende a clientes de baixa renda, acreditamos que eles contratem vários produtos com baixos valores (Comprovada).

# %%
fig = px.scatter(client.sample(10000), x = "qtd_oper", y = "vlr_saldo")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7d1a844b-b228-4a6a-84fa-f53cdfc92c8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d1a844b-b228-4a6a-84fa-f53cdfc92c8b")) {                    Plotly.newPlot(                        "7d1a844b-b228-4a6a-84fa-f53cdfc92c8b",                        [{"hovertemplate":"qtd_oper=%{x}<br>vlr_saldo=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[9.0,10.0,2.0,18.0,2.0,2.0,21.0,22.0,36.0,6.0,11.0,7.0,6.0,10.0,33.0,null,10.0,11.0,5.0,4.0,7.0,null,6.0,18.0,26.0,13.0,17.0,13.0,11.0,6.0,null,8.0,8.0,13.0,26.0,10.0,13.0,10.0,10.0,24.0,49.0,13.0,null,4.0,15.0,2.0,8.0,5.0,11.0,3.0,4.0,8.0,null,9.0,19.0,15.0,8.0,4.0,null,11.0,13.0,11.0,3.0,9.0,4.0,29.0,14.0,7.0,11.0,1.0,14.0,15.0,22.0,6.0,10.0,9.0,8.0,9.0,null,8.0,13.0,2.0,28.0,12.0,29.0,6.0,5.0,8.0,11.0,10.0,29.0,11.0,3.0,12.0,16.0,null,4.0,11.0,11.0,8.0,7.0,7.0,null,4.0,13.0,11.0,1.0,18.0,null,11.0,18.0,22.0,23.0,7.0,7.0,null,7.0,9.0,3.0,8.0,5.0,4.0,20.0,11.0,37.0,5.0,null,35.0,null,22.0,9.0,2.0,4.0,11.0,6.0,8.0,null,9.0,7.0,22.0,null,12.0,8.0,12.0,16.0,17.0,3.0,10.0,19.0,20.0,26.0,11.0,19.0,2.0,16.0,9.0,7.0,13.0,7.0,23.0,19.0,15.0,null,41.0,11.0,15.0,17.0,2.0,8.0,8.0,6.0,14.0,9.0,26.0,15.0,8.0,29.0,15.0,5.0,6.0,7.0,5.0,6.0,7.0,13.0,13.0,1.0,30.0,24.0,36.0,null,4.0,13.0,18.0,7.0,7.0,7.0,3.0,11.0,12.0,3.0,10.0,12.0,6.0,null,5.0,16.0,11.0,null,29.0,31.0,2.0,10.0,2.0,17.0,17.0,2.0,14.0,3.0,null,5.0,36.0,4.0,12.0,null,10.0,5.0,null,13.0,10.0,50.0,28.0,20.0,16.0,11.0,10.0,18.0,18.0,11.0,19.0,14.0,11.0,18.0,4.0,13.0,14.0,22.0,28.0,5.0,6.0,null,null,3.0,2.0,5.0,10.0,0.0,null,1.0,16.0,null,null,14.0,16.0,null,12.0,24.0,13.0,15.0,12.0,3.0,9.0,13.0,null,16.0,null,null,10.0,17.0,33.0,8.0,4.0,5.0,7.0,12.0,15.0,4.0,21.0,4.0,6.0,15.0,19.0,31.0,6.0,23.0,null,17.0,13.0,2.0,7.0,5.0,12.0,17.0,15.0,7.0,14.0,5.0,25.0,5.0,9.0,27.0,14.0,null,36.0,5.0,21.0,15.0,11.0,17.0,5.0,4.0,16.0,13.0,13.0,6.0,11.0,null,43.0,23.0,11.0,5.0,27.0,7.0,2.0,10.0,5.0,null,19.0,8.0,5.0,26.0,4.0,4.0,null,18.0,null,4.0,null,6.0,null,11.0,null,26.0,12.0,5.0,16.0,14.0,1.0,1.0,23.0,null,null,18.0,1.0,8.0,22.0,8.0,11.0,6.0,11.0,13.0,17.0,5.0,3.0,10.0,24.0,4.0,20.0,13.0,5.0,null,25.0,14.0,5.0,null,1.0,17.0,5.0,1.0,4.0,9.0,19.0,13.0,3.0,16.0,5.0,20.0,12.0,49.0,22.0,9.0,8.0,12.0,15.0,11.0,11.0,9.0,7.0,3.0,5.0,null,21.0,9.0,null,15.0,16.0,25.0,null,18.0,20.0,6.0,11.0,5.0,0.0,9.0,14.0,null,10.0,3.0,5.0,6.0,8.0,6.0,11.0,4.0,33.0,14.0,null,2.0,null,5.0,10.0,null,17.0,11.0,12.0,48.0,18.0,10.0,24.0,23.0,11.0,null,20.0,13.0,1.0,38.0,21.0,11.0,4.0,13.0,14.0,21.0,23.0,28.0,null,23.0,7.0,5.0,null,22.0,14.0,8.0,8.0,4.0,12.0,null,20.0,43.0,10.0,16.0,17.0,14.0,null,13.0,6.0,21.0,5.0,9.0,18.0,48.0,31.0,7.0,24.0,7.0,15.0,11.0,8.0,null,6.0,5.0,23.0,16.0,13.0,11.0,22.0,null,8.0,17.0,15.0,22.0,null,null,24.0,2.0,6.0,17.0,null,4.0,16.0,14.0,22.0,16.0,14.0,3.0,10.0,null,8.0,29.0,25.0,null,7.0,6.0,12.0,14.0,13.0,9.0,15.0,7.0,null,26.0,9.0,9.0,2.0,9.0,6.0,16.0,2.0,12.0,23.0,11.0,6.0,0.0,30.0,20.0,20.0,13.0,null,3.0,14.0,6.0,18.0,null,null,3.0,5.0,11.0,28.0,22.0,null,8.0,7.0,24.0,27.0,null,0.0,25.0,19.0,null,null,12.0,20.0,9.0,52.0,2.0,null,null,16.0,1.0,10.0,null,null,6.0,5.0,4.0,27.0,null,6.0,27.0,null,11.0,null,5.0,7.0,6.0,1.0,12.0,22.0,24.0,6.0,28.0,12.0,null,18.0,21.0,18.0,11.0,33.0,19.0,4.0,5.0,null,30.0,5.0,9.0,33.0,12.0,6.0,null,11.0,23.0,14.0,9.0,24.0,15.0,29.0,17.0,12.0,9.0,6.0,null,8.0,12.0,8.0,19.0,19.0,5.0,38.0,null,3.0,13.0,16.0,10.0,9.0,5.0,20.0,9.0,null,36.0,3.0,null,null,15.0,8.0,19.0,null,null,12.0,6.0,38.0,12.0,10.0,3.0,null,18.0,21.0,13.0,92.0,null,6.0,5.0,9.0,30.0,22.0,11.0,1.0,null,null,8.0,null,12.0,null,7.0,4.0,22.0,11.0,null,20.0,11.0,8.0,null,13.0,20.0,19.0,5.0 ...

# %% [markdown]
# #Remoção de colunas

# %% [markdown]
# Após a análise preliminar com os dados, vamos observar quais features seriam interessantes segundo o método KBest da biblioteca SKLearna, que verifica quais colunas são mais interessantes para o resultado que buscamos.

# %% [markdown]
# ## Remoção das colunas que não iremos utilizar da tabela de clientes

# %%
client = client.drop('cod_rating', axis=1)

# %%
client = client.drop('ind_novo_cli', axis=1)

# %%
client = client.drop('num_cpf_hash', axis=1)

# %%
client = client.drop('anomes', axis=1)

# %% [markdown]
# ## Remoção das colunas que não iremos utilizar da tabela de não clientes

# %%
not_client = not_client.drop('vlr_saldo', axis=1)

# %%
not_client = not_client.drop('cod_rating', axis=1)

# %%
not_client = not_client.drop('ind_atrito', axis=1)

# %%
not_client = not_client.drop('ind_engaj', axis=1)

# %%
not_client = not_client.drop('num_cpf_hash', axis=1)

# %%
not_client = not_client.drop('num_produtos', axis=1)

# %%
not_client = not_client.drop('anomes', axis=1)

# %%
not_client = not_client.drop('qtd_oper', axis=1)

# %% [markdown]
# # Remoção das linhas com valores vazios (NaN)

# %%
client = client.dropna()
not_client = not_client.dropna()

# %% [markdown]
# #Visualização dos dados
# ###Tabela completa:

# %%
df.describe()
# Out:
#          anomes   vlr_credito     vlr_saldo  num_atend_atrs      vlr_score  \
# count  860680.0  4.686030e+05  4.447680e+05   860680.000000  851123.000000
# mean   202204.0  3.425695e+04  5.754732e+03        0.000675     440.868065
# std         0.0  7.082078e+04  1.033775e+04        0.029453     205.964544
# min    202204.0  0.000000e+00  1.000000e-02        0.000000       0.000000
# 25%    202204.0  3.512840e+03  9.997700e+02        0.000000     304.000000
# 50%    202204.0  1.536009e+04  2.435460e+03        0.000000     402.000000
# 75%    202204.0  3.634693e+04  6.724953e+03        0.000000     575.000000
# max    202204.0  1.034811e+07  1.666399e+06        6.000000    1000.000000
#
#         num_produtos      num_atend       qtd_oper      qtd_reclm  \
# count  477651.000000  860680.000000  468603.000000  860680.000000
# mean        1.777785       0.002469      12.580972       0.000066
# std         1.188577       0.064618      11.026851       0.008138
# min         1.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       5.000000       0.000000
# 50%         1.000000       0.000000      10.000000       0.000000
# 75%         2.000000       0.000000      17.000000       0.000000
# max        14.000000       9.000000     265.000000       1.000000
#
#            qtd_restr     ind_atrito      ind_engaj   ind_novo_cli
# count  604604.000000  860680.000000  860680.000000  860680.000000
# mean        3.044331       0.000251       0.172231       0.198563
# std         3.792886       0.015840       0.377582       0.398918
# min         1.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000       0.000000
# 50%         2.000000       0.000000       0.000000       0.000000
# 75%         4.000000       0.000000       0.000000       0.000000
# max       217.000000       1.000000       1.000000       1.000000

# %% [markdown]
# ###Tabela clientes:

# %%
client.describe()
# Out:
#         vlr_credito      vlr_saldo  num_atend_atrs      vlr_score  \
# count  1.856740e+05  185674.000000   185674.000000  185674.000000
# mean   4.111866e+04    5563.932289        0.000937     375.721507
# std    6.712991e+04    9555.193118        0.032477     143.472515
# min    0.000000e+00       0.010000        0.000000       0.000000
# 25%    7.907640e+03     880.000000        0.000000     285.000000
# 50%    2.074701e+04    2184.815000        0.000000     384.000000
# 75%    4.597607e+04    6188.030000        0.000000     462.000000
# max    3.699561e+06  741055.970000        2.000000     973.000000
#
#         num_produtos      num_atend       qtd_oper      qtd_reclm  \
# count  185674.000000  185674.000000  185674.000000  185674.000000
# mean        1.959763       0.003582      14.080033       0.000151
# std         1.244910       0.074936      10.516921       0.012279
# min         1.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.000000       7.000000       0.000000
# 50%         2.000000       0.000000      12.000000       0.000000
# 75%         3.000000       0.000000      18.000000       0.000000
# max        13.000000       5.000000     265.000000       1.000000
#
#            qtd_restr     ind_atrito      ind_engaj
# count  185674.000000  185674.000000  185674.000000
# mean        3.307744       0.000517       0.340893
# std         3.745876       0.022733       0.474011
# min         1.000000       0.000000       0.000000
# 25%         1.000000       0.000000       0.000000
# 50%         2.000000       0.000000       0.000000
# 75%         4.000000       0.000000       1.000000
# max       110.000000       1.000000       1.000000

# %% [markdown]
# ###Tabela não clientes:

# %%
not_client.describe()
# Out:
#         vlr_credito  num_atend_atrs     vlr_score     num_atend     qtd_reclm  \
# count  5.922000e+04    59220.000000  59220.000000  59220.000000  59220.000000
# mean   1.116576e+04        0.000152    287.116211      0.000540      0.000017
# std    4.897024e+04        0.013628    133.671909      0.025326      0.004109
# min    0.000000e+00        0.000000      0.000000      0.000000      0.000000
# 25%    0.000000e+00        0.000000    176.000000      0.000000      0.000000
# 50%    9.382750e+02        0.000000    274.000000      0.000000      0.000000
# 75%    5.099010e+03        0.000000    376.000000      0.000000      0.000000
# max    7.638867e+06        2.000000    961.000000      2.000000      1.000000
#
#           qtd_restr  ind_novo_cli
# count  59220.000000  59220.000000
# mean       3.291692      0.276292
# std        3.780653      0.447167
# min        1.000000      0.000000
# 25%        1.000000      0.000000
# 50%        2.000000      0.000000
# 75%        4.000000      1.000000
# max      217.000000      1.000000

# %% [markdown]
# # Feature Engineering com o uso do SKLearn

# %% [markdown]
# ##Atritado

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif, mutual_info_classif

# %%
# Identificar as variáveis entre colunas de análise e coluna de resposta do teste
x = client.drop(['ind_atrito', 'ind_engaj'], axis=1)
y = client['ind_atrito']

# %%
# Chamar o método que verifica os melhores parâmetros f_classif que utiliza da progressão linear para ajustar os dados
f_classif = SelectKBest(score_func=f_classif, k=4)

# %%
fit = f_classif.fit(x, y)

# %%
features = fit.transform(x)

# %%
# Fazer aparecer o nome das colunas que o método julgou interessante
cols = fit.get_support(indices=True)
x.iloc[:, cols]
# Out:
#           vlr_credito  vlr_saldo  num_atend_atrs  qtd_reclm
# 11171813     37071.44    8241.16             0.0        0.0
# 11171820    115411.38    6394.76             0.0        0.0
# 11171830     44153.68   27017.68             0.0        0.0
# 11171834    417647.99   32492.43             0.0        0.0
# 11171839     27663.96    1780.23             0.0        0.0
# ...               ...        ...             ...        ...
# 12032476     58167.65    1888.88             0.0        0.0
# 12032484     36333.58    5942.14             0.0        0.0
# 12032485     43054.69    2620.89             0.0        0.0
# 12032487     21959.05    4017.00             0.0        0.0
# 12032490     30268.92    1631.88             0.0        0.0
#
# [185674 rows x 4 columns]

# %% [markdown]
# Com este novo teste, podemos perceber que estávamos na direção correta em nossa análise, mas que deixamos passar a coluna do num_atend, que julgamos não ser relevante a resposta final, mas que o algoritmo considera importante.

# %% [markdown]
# ##Engajado

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif, mutual_info_classif

# %%
#Definindo as variáveis que serão usadas para a feature engineering
x = client.drop(['ind_atrito', 'ind_engaj'], axis = 1)
y = client['ind_engaj']

# %%
## Chamar o método que verifica os melhores parâmetros f_classif que utiliza da progressão linear para ajustar os dados e utilizando as top 4 features
f_classif = SelectKBest (score_func=f_classif, k=4)

# %%
fit = f_classif.fit(x, y)

# %%
features = fit.transform(x)

# %%
cols = fit.get_support(indices=True)
x.iloc[:, cols]
# Out:
#           vlr_credito  vlr_saldo  num_produtos  qtd_oper
# 11171813     37071.44    8241.16           2.0      13.0
# 11171820    115411.38    6394.76           2.0      20.0
# 11171830     44153.68   27017.68           1.0      12.0
# 11171834    417647.99   32492.43           3.0      25.0
# 11171839     27663.96    1780.23           5.0      12.0
# ...               ...        ...           ...       ...
# 12032476     58167.65    1888.88           1.0      18.0
# 12032484     36333.58    5942.14           4.0      40.0
# 12032485     43054.69    2620.89           2.0      17.0
# 12032487     21959.05    4017.00           1.0      15.0
# 12032490     30268.92    1631.88           1.0      17.0
#
# [185674 rows x 4 columns]

# %% [markdown]
# ##Novo cliente

# %%
#Importar a biblioteca
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif, mutual_info_classif

# %%
# Identificar as variáveis entre colunas de análise e coluna de resposta do teste
x = not_client.drop(['ind_novo_cli'], axis=1)
y = not_client['ind_novo_cli']

# %%
# Chamar o método que verifica os melhores parâmetros f_classif que utiliza da progressão linear para ajustar os dados
f_classif = SelectKBest(score_func = f_classif, k=4)

# %%
fit = f_classif.fit(x, y)

# %%
features = fit.transform(x)

# %%
# Fazer aparecer o nome das colunas que o método julgou interessante
cols = fit.get_support(indices=True)
x.iloc[:, cols]
# Out:
#           vlr_credito  num_atend_atrs  vlr_score  qtd_restr
# 11171814         0.00             0.0      523.0        1.0
# 11171816     16411.68             0.0      415.0        3.0
# 11171822     39486.40             0.0      159.0        8.0
# 11171843         0.00             0.0      315.0       10.0
# 11171846      1821.36             0.0      566.0        3.0
# ...               ...             ...        ...        ...
# 12032421         0.00             0.0      274.0        2.0
# 12032441         0.00             0.0      382.0        1.0
# 12032450         0.00             0.0      297.0        2.0
# 12032455      5392.63             0.0      168.0        9.0
# 12032477      2623.28             0.0      431.0       12.0
#
# [59220 rows x 4 columns]

# %% [markdown]
# # Normalização e padronização das colunas

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler
plt.hist(client['vlr_score'])
# Out:
# (array([ 3328., 22209., 22488., 49693., 49079., 33881.,  2315.,  1262.,
#           798.,   621.]),
#  array([  0. ,  97.3, 194.6, 291.9, 389.2, 486.5, 583.8, 681.1, 778.4,
#         875.7, 973. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Cliente

# %%
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(client)
client = pd.DataFrame(data=scaled_features, columns=client.columns)

# %%
client
# Out:
#         vlr_credito  vlr_saldo  num_atend_atrs  vlr_score  num_produtos  \
# 0          0.010020   0.011121             0.0   0.537513      0.083333
# 1          0.031196   0.008629             0.0   0.353546      0.083333
# 2          0.011935   0.036458             0.0   0.417266      0.000000
# 3          0.112891   0.043846             0.0   0.149024      0.166667
# 4          0.007478   0.002402             0.0   0.362795      0.333333
# ...             ...        ...             ...        ...           ...
# 185669     0.015723   0.002549             0.0   0.503597      0.000000
# 185670     0.009821   0.008018             0.0   0.552929      0.250000
# 185671     0.011638   0.003537             0.0   0.449126      0.083333
# 185672     0.005936   0.005421             0.0   0.421377      0.000000
# 185673     0.008182   0.002202             0.0   0.368962      0.000000
#
#         num_atend  qtd_oper  qtd_reclm  qtd_restr  ind_atrito  ind_engaj
# 0             0.0  0.049057        0.0   0.000000         0.0        1.0
# 1             0.0  0.075472        0.0   0.000000         0.0        1.0
# 2             0.0  0.045283        0.0   0.110092         0.0        1.0
# 3             0.0  0.094340        0.0   0.100917         0.0        1.0
# 4             0.0  0.045283        0.0   0.009174         0.0        0.0
# ...           ...       ...        ...        ...         ...        ...
# 185669        0.0  0.067925        0.0   0.036697         0.0        0.0
# 185670        0.0  0.150943        0.0   0.000000         0.0        1.0
# 185671        0.0  0.064151        0.0   0.064220         0.0        0.0
# 185672        0.0  0.056604        0.0   0.027523         0.0        0.0
# 185673        0.0  0.064151        0.0   0.045872         0.0        1.0
#
# [185674 rows x 11 columns]

# %% [markdown]
# ## Não cliente

# %%
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(not_client)
not_client = pd.DataFrame(data=scaled_features, columns=not_client.columns)

# %%
not_client
# Out:
#        vlr_credito  num_atend_atrs  vlr_score  num_atend  qtd_reclm  \
# 0         0.000000             0.0   0.544225        0.0        0.0
# 1         0.002148             0.0   0.431842        0.0        0.0
# 2         0.005169             0.0   0.165453        0.0        0.0
# 3         0.000000             0.0   0.327784        0.0        0.0
# 4         0.000238             0.0   0.588970        0.0        0.0
# ...            ...             ...        ...        ...        ...
# 59215     0.000000             0.0   0.285120        0.0        0.0
# 59216     0.000000             0.0   0.397503        0.0        0.0
# 59217     0.000000             0.0   0.309053        0.0        0.0
# 59218     0.000706             0.0   0.174818        0.0        0.0
# 59219     0.000343             0.0   0.448491        0.0        0.0
#
#        qtd_restr  ind_novo_cli
# 0       0.000000           1.0
# 1       0.009259           0.0
# 2       0.032407           0.0
# 3       0.041667           0.0
# 4       0.009259           0.0
# ...          ...           ...
# 59215   0.004630           0.0
# 59216   0.000000           1.0
# 59217   0.004630           0.0
# 59218   0.037037           0.0
# 59219   0.050926           0.0
#
# [59220 rows x 7 columns]

# %% [markdown]
# # Salvando a base de dados manipulada em novos arquivos csv

# %%
# Importamos a biblioteca drive do google.colab
from google.colab import drive
         
# Estabelecemos os caminhos para o download poder ser executado
drive.mount(r'/content/drive')
path = r'/content/drive/My Drive/Pandevs/client.csv'

# Baixando nosso df no formato de csv em nosso drive
with open(path, 'w', encoding = 'utf-8-sig') as f:
  client.to_csv(f)
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-2a98f3e1e64e> in <module>
#       7
#       8 # Baixando nosso df no formato de csv em nosso drive
# ----> 9 with open(path, 'w', encoding = 'utf-8-sig') as f:
#      10   client.to_csv(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Pandevs/client.csv'

# %%
# Estabelecemos os caminhos para o download poder ser executado
drive.mount(r'/content/drive')
path = r'/content/drive/My Drive/Pandevs/not_client.csv'

# Baixando nosso df no formato de csv em nosso drive
with open(path, 'w', encoding = 'utf-8-sig') as f:
  not_client.to_csv(f)

# %% [markdown]
# ## Novo cliente

# %% [markdown]
# ### Criando o modelo

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
cols = ['vlr_credito', 'qtd_reclm', 'vlr_score', 'qtd_restr']

# %%
# Dividindo x e y
x = not_client[cols]
y = not_client['ind_novo_cli']

# %%
# Dividindo dados para treino e dados para teste
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.3, 
                                                    random_state = 42)

# %%
# Treinando o modelo
model = LinearRegression().fit(x_train, y_train)

# %%
# Fazendo as predições
y_pred = model.predict(x_test)
y_pred

# %% [markdown]
# ### Avaliando o modelo

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# #### Mean squared error (MSE):
# Em português, erro quadrático médio, essa métrica penaliza mais erros maiores, já que os erros (diferença entre o valor previsto e o correto) são elevados ao quadrado.

# %%
mean_squared_error(y_test, y_pred)

# %% [markdown]
# #### Mean absolute error (MAE):
# Em português, erro absoluto médio, essa métrica basicamente faz a média do erro absoluto de cada previsão.

# %%
mean_absolute_error(y_test, y_pred)

# %% [markdown]
# #### R2:
# O erro "R quadrado" é uma métrica que varia entre -∞ e 1 e é uma razão que indica o quão bom o nosso modelo está em comparação com um modelo "naive", que faz a predição com base no valor médio do target. Quanto maior seu valor, melhor é nosso modelo com relação a esse modelo mais simplista.

# %%
r2_score(y_test, y_pred)

# %% [markdown]
# # Seleção de Features

# %% [markdown]
# Iremos selecionar as features que são interessantes para identificar se um cliente é caracterizado como um novo cliente.

# %%
# Nesta variável estamos armazenando os clientes que têm índice 1 na coluna ind_novo_cli
new_client_ind_1 = not_client[not_client.ind_novo_cli == 1] 

# Nesta variável estamos armazenando os clientes que têm índice 0 na coluna ind_novo_cli
new_client_ind_0 = not_client[not_client.ind_novo_cli != 1]

# %% [markdown]
# ## Novo cliente

# %% [markdown]
# Relação entre o desejo do banco em ter um cliente (0 = quer como cliente; 1 = não quer como cliente) e o Score do mercado.

# %%
fig = px.bar(y = [new_client_ind_1['vlr_score'].mean(), new_client_ind_0['vlr_score'].mean()], x = ['Clientes desejados', 'Clientes não desejados'])#foi passado uma lista com 2 dados dentro de uma máscara com a média dos Scores de clientes que o banco deseja, ou não para compararmos.
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ce5c8c0b-11bf-44ce-842a-670997a0784a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce5c8c0b-11bf-44ce-842a-670997a0784a")) {                    Plotly.newPlot(                        "ce5c8c0b-11bf-44ce-842a-670997a0784a",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Clientes desejados","Clientes n\u00e3o desejados"],"xaxis":"x","y":[0.4380497131687964,0.2455943250195003],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3 ...

# %% [markdown]
# Relação entre o desejo do banco em ter um cliente (0 = quer como cliente; 1 = não quer como cliente) e o crédito que ele tem no mercado.

# %%
fig = px.bar(y = [new_client_ind_1['vlr_credito'].mean(), new_client_ind_0['vlr_credito'].mean()], x = ['Crédito do cliente desejado','Crédito do cliente não desejado'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="220bb50f-4664-4e1a-8b18-b95a80b609f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("220bb50f-4664-4e1a-8b18-b95a80b609f0")) {                    Plotly.newPlot(                        "220bb50f-4664-4e1a-8b18-b95a80b609f0",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Cr\u00e9dito do cliente desejado","Cr\u00e9dito do cliente n\u00e3o desejado"],"xaxis":"x","y":[0.0017615162517303632,0.0013472439954250843],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks" ...

# %% [markdown]
# Relação entre o desejo do banco em ter um cliente (0 = quer como cliente; 1 = não quer como cliente) e a quantidade de restrições que ele tem no mercado.

# %%
fig = px.bar(y = [new_client_ind_1['qtd_restr'].mean(), new_client_ind_0['qtd_restr'].mean()], x = ['Restritivos do cliente desejado', 'Restritivos do cliente não desejado'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7ca2bee1-d387-4ffb-b24e-a391a4f4ec60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ca2bee1-d387-4ffb-b24e-a391a4f4ec60")) {                    Plotly.newPlot(                        "7ca2bee1-d387-4ffb-b24e-a391a4f4ec60",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Restritivos do cliente desejado","Restritivos do cliente n\u00e3o desejado"],"xaxis":"x","y":[0.0016484673158673891,0.014030830494501219],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %% [markdown]
# ##Cliente engajado

# %% [markdown]
# Iremos selecionar as features que são interessantes para identificar se um cliente é caracterizado como um cliente engajado.

# %%
client_engaged = client[client.ind_engaj == 1]#Nesta variável estamos armazenando os clientes que têm índice 1 na coluna ind_novo_cli
client_not_engaged = client[client.ind_engaj != 1]#Nesta variável estamos armazenando os clientes que têm índice 0 na coluna ind_novo_cli

# %% [markdown]
# Relação entre o banco acreditar que um cliente é engajado (0 = é engajado; 1 = não é engajado) e a quantidade de produtos que ele tem.

# %%
fig = px.bar(y = [client_engaged['num_produtos'].mean(), client_not_engaged['num_produtos'].mean()], x = ['Produtos de clientes engajados', ' Produtos de clientes não engajados'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="497590d1-4eaa-45d4-9d47-4db739b7a5e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("497590d1-4eaa-45d4-9d47-4db739b7a5e1")) {                    Plotly.newPlot(                        "497590d1-4eaa-45d4-9d47-4db739b7a5e1",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Produtos de clientes engajados"," Produtos de clientes n\u00e3o engajados"],"xaxis":"x","y":[0.12674908497248336,0.05579116242710487],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}," ...

# %% [markdown]
# Relação entre o banco acreditar que um cliente é engajado (0 = é engajado; 1 = não é engajado) e a quantidade de operações que ele tem.

# %%
fig = px.bar(y = [client_engaged['qtd_oper'].mean(), client_not_engaged['qtd_oper'].mean()], x = ['Operações de clientes engajados', ' Operações de clientes não engajados'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ac5a91e1-86da-4330-93b2-337bf9a0b714" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac5a91e1-86da-4330-93b2-337bf9a0b714")) {                    Plotly.newPlot(                        "ac5a91e1-86da-4330-93b2-337bf9a0b714",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Opera\u00e7\u00f5es de clientes engajados"," Opera\u00e7\u00f5es de clientes n\u00e3o engajados"],"xaxis":"x","y":[0.06951289782644013,0.044660023832551125],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outline ...

# %% [markdown]
# Relação entre o banco acreditar que um cliente é engajado (0 = é engajado; 1 = não é engajado) e a quantidade de crédito que ele tem.

# %%
fig = px.bar(y = [client_engaged['vlr_credito'].mean(), client_not_engaged['vlr_credito'].mean()], x = ['Crédito do cliente engajado', 'Crédito do cliente não engajado'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="01d07a83-fd38-43b7-aece-29f16461a2aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01d07a83-fd38-43b7-aece-29f16461a2aa")) {                    Plotly.newPlot(                        "01d07a83-fd38-43b7-aece-29f16461a2aa",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Cr\u00e9dito do cliente engajado","Cr\u00e9dito do cliente n\u00e3o engajado"],"xaxis":"x","y":[0.012896167896178945,0.010192964628965096],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":" ...

# %% [markdown]
# Relação entre o banco acreditar que um cliente é engajado (0 = é engajado; 1 = não é engajado) e a quantidade de saldo que ele tem.

# %%
fig = px.bar(y = [client_engaged['vlr_saldo'].mean(), client_not_engaged['vlr_saldo'].mean()], x = ['Saldo do cliente engajado', 'Saldo cliente não engajado'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="abb8ca0f-9745-43c7-822e-e50869fe6ce8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abb8ca0f-9745-43c7-822e-e50869fe6ce8")) {                    Plotly.newPlot(                        "abb8ca0f-9745-43c7-822e-e50869fe6ce8",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Saldo do cliente engajado","Saldo cliente n\u00e3o engajado"],"xaxis":"x","y":[0.010568858002426905,0.005925061497880505],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatt ...

# %% [markdown]
# ##Cliente atritado

# %%
client_fretted = df[df.ind_atrito == 1]#Nesta variável estamos armazenando os clientes que têm índice 1 na coluna ind_atrito
client_not_fretted = df[df.ind_atrito != 1]#Nesta variável estamos armazenando os clientes que têm índice 0 na coluna ind_atrito

# %% [markdown]
# Relação entre o banco acreditar que um cliente é atritado (0 = é atritado; 1 = não é atritado) e a quantidade de operações.

# %%
fig = px.bar(y = [client_fretted['qtd_oper'].mean(), client_not_fretted['qtd_oper'].mean()], x = ['Operações de clientes atritados', ' Operações clientes não atritados'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="64bc758c-f21c-4fea-9666-8ec77a0de516" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64bc758c-f21c-4fea-9666-8ec77a0de516")) {                    Plotly.newPlot(                        "64bc758c-f21c-4fea-9666-8ec77a0de516",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Opera\u00e7\u00f5es de clientes atritados"," Opera\u00e7\u00f5es clientes n\u00e3o atritados"],"xaxis":"x","y":[15.15979381443299,12.579903460437352],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth": ...

# %% [markdown]
# Relação entre o banco acreditar que um cliente é atritado (0 = é atritado; 1 = não é atritado) e a quantidade de produtos.

# %%
fig = px.bar(y = [client_fretted['num_produtos'].mean(), client_not_fretted['num_produtos'].mean()], x = ['Produtos de clientes atritados', 'Produtos de clientes não atritados'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a91381e7-888b-48e6-b0b4-01f70c69641b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a91381e7-888b-48e6-b0b4-01f70c69641b")) {                    Plotly.newPlot(                        "a91381e7-888b-48e6-b0b4-01f70c69641b",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Produtos de clientes atritados","Produtos de clientes n\u00e3o atritados"],"xaxis":"x","y":[2.082051282051282,1.7776611876277604],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type ...

# %% [markdown]
# Relação entre o banco acreditar que um cliente é atritado (0 = é atritado; 1 = não é atritado) e o valor do Score.

# %%
fig = px.bar(y = [client_fretted['vlr_score'].mean(), client_not_fretted['vlr_score'].mean()], x = ['Score dos clientes atritados', 'Score dos clienets não atritados'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="85a041ab-ba5f-446e-858c-fd84b0fa7568" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85a041ab-ba5f-446e-858c-fd84b0fa7568")) {                    Plotly.newPlot(                        "85a041ab-ba5f-446e-858c-fd84b0fa7568",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Score dos clientes atritados","Score dos clienets n\u00e3o atritados"],"xaxis":"x","y":[536.5092592592592,440.8437866887921],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sc ...

# %% [markdown]
# Relação entre o banco acreditar que um cliente é atritado (0 = é atritado; 1 = não é atritado) e o valor de crédito.

# %%
fig = px.bar(y = [client_fretted['vlr_credito'].mean(), client_not_fretted['vlr_credito'].mean()], x = ['Crédito dos clientes atritados', 'Crédito dos clientes não atritados'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0199e1a0-4611-4d35-b134-ff85108abdb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0199e1a0-4611-4d35-b134-ff85108abdb1")) {                    Plotly.newPlot(                        "0199e1a0-4611-4d35-b134-ff85108abdb1",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Cr\u00e9dito dos clientes atritados","Cr\u00e9dito dos clientes n\u00e3o atritados"],"xaxis":"x","y":[61213.44726804124,34245.78451677913],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":" ...

# %% [markdown]
# Relação entre o banco acreditar que um cliente é atritado (0 = é atritado; 1 = não é atritado) e o valor do saldo.

# %%
fig = px.bar(y = [client_fretted['vlr_saldo'].mean(), client_not_fretted['vlr_saldo'].mean()], x = ['Saldo dos clientes atritados', 'Saldo dos clientes não atritatados'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d9cee05a-17dc-46a0-abc9-16e3b992c8e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9cee05a-17dc-46a0-abc9-16e3b992c8e9")) {                    Plotly.newPlot(                        "d9cee05a-17dc-46a0-abc9-16e3b992c8e9",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Saldo dos clientes atritados","Saldo dos clientes n\u00e3o atritatados"],"xaxis":"x","y":[11627.76917475728,5752.010400331839],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":" ...

# %% [markdown]
# #  Visualização de Jornada do usuário
# 1. Atritado
#     Foram coletados 3 CPFs para comparar as ações de acordo com as safras

# %%
# Coletar o ID do cpf a partir da última safra
df[(df.anomes == 202204) & (df.ind_atrito == 1)].head()
# Out:
#           anomes                                       num_cpf_hash  \
# 11179869  202204  fd9e5c9a7d3139e2d640ba1786cf4ae912451f3d402ec2...
# 11182144  202204  fceeebd633697423bef73561b86bd94d436b114393aa4a...
# 11182479  202204  fcd567dae19a734959b3676fde6f1c18f98edcd6e9afd1...
# 11184523  202204  fc336fda93ad59e0bf2e673cbd8bb0d87d4ec3034871d7...
# 11195680  202204  f8ec4856c3803e46edc8a0cbcc0041d7e9d28bfcf741bc...
#
#           vlr_credito  vlr_saldo  num_atend_atrs  vlr_score  num_produtos  \
# 11179869     36356.50    1167.83             0.0      360.0           1.0
# 11182144     32166.70   21905.94             0.0        0.0           3.0
# 11182479    111980.77   12067.74             0.0      738.0           2.0
# 11184523          NaN      22.50             0.0      435.0           NaN
# 11195680     11525.84     869.02             0.0      350.0           4.0
#
#           num_atend  qtd_oper  qtd_reclm  qtd_restr cod_rating  ind_atrito  \
# 11179869        0.0      16.0        0.0        3.0          A         1.0
# 11182144        0.0      11.0        1.0        1.0          A         1.0
# 11182479        0.0      14.0        0.0        NaN          A         1.0
# 11184523        0.0       NaN        1.0        NaN         HH         1.0
# 11195680        0.0      16.0        1.0        5.0          F         1.0
#
#           ind_engaj  ind_novo_cli
# 11179869        0.0           0.0
# 11182144        0.0           0.0
# 11182479        1.0           0.0
# 11184523        0.0           0.0
# 11195680        0.0           0.0

# %%
# Coletar o número completo do cpf para analisar cada safra
new_df.loc[9269696,'num_cpf_hash']
# Out:
# '08f3b339ea8529cf59ac650b9a8eeafc14e5718af604fa2fe9bf52849d8abb78'

# %%
# Visualização de cada mês de um cpf
new_df[(new_df.num_cpf_hash == 'fe7728cf4b196eedfae889dff044eca220e42c72bb837f158c420649fd738e2d')]
# Out:
#           anomes                                       num_cpf_hash  \
# 5987      202104  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 1005846   202105  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 1981546   202106  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 2940237   202107  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 3884276   202108  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 4812711   202109  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 5726972   202110  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 6636258   202111  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 7537481   202112  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 8427216   202201  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 9305830   202202  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 10180231  202203  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
# 11176989  202204  fe7728cf4b196eedfae889dff044eca220e42c72bb837f...
#
#           vlr_credito  vlr_saldo  num_atend_atrs  vlr_score  num_produtos  \
# 5987         44012.30    1319.90             NaN        NaN           1.0
# 1005846      43863.89    1344.55             NaN      396.0           1.0
# 1981546      43632.71    1337.35             NaN      394.0           1.0
# 2940237      60705.58    1330.82             NaN      360.0           1.0
# 3884276      61309.08    1324.16             NaN      276.0           1.0
# 4812711      68908.94    1316.60             NaN      334.0           1.0
# 5726972      68255.25    1309.68             NaN      368.0           1.0
# 6636258      70944.92    1301.85             NaN        NaN           1.0
# 7537481      71859.22    1294.65             NaN      366.0           1.0
# 8427216      71191.76    1287.32             NaN      379.0           1.0
# 9305830      70349.24    1277.56             NaN      400.0           1.0
# 10180231     73449.31    1269.91             NaN      407.0           1.0
# 11176989     72748.59    1261.37             NaN      388.0           1.0
#
#           num_atend  qtd_oper  qtd_reclm  qtd_restr vlr_renda cod_rating  \
# 5987            NaN      17.0        1.0        NaN       NaN          A
# 1005846         NaN      16.0        NaN        NaN       NaN          A
# 1981546         NaN      16.0        NaN        NaN       NaN          A
# 2940237         NaN      20.0        NaN        NaN       NaN          A
# 3884276         NaN      18.0        NaN        NaN       NaN          A
# 4812711         NaN      18.0        NaN        NaN       NaN          A
# 5726972         NaN      18.0        NaN        NaN       NaN          A
# 6636258         NaN      18.0        NaN        NaN       NaN          A
# 7537481         NaN      19.0        NaN        NaN       NaN          A
# 8427216         NaN      18.0        NaN        NaN       NaN          A
# 9305830         NaN      18.0        NaN        NaN       NaN          A
# 10180231        NaN      20.0        NaN        NaN   5700,00          A
# 11176989        NaN      20.0        NaN        NaN       NaN          A
#
#           ind_atrito  ind_engaj  ind_novo_cli
# 5987             1.0        1.0           NaN
# 1005846          NaN        NaN           NaN
# 1981546          NaN        NaN           NaN
# 2940237          NaN        NaN           NaN
# 3884276          NaN        NaN           NaN
# 4812711          NaN        NaN           NaN
# 5726972          NaN        NaN           NaN
# 6636258          NaN        NaN           NaN
# 7537481          NaN        NaN           NaN
# 8427216          NaN        NaN           NaN
# 9305830          NaN        NaN           NaN
# 10180231         NaN        NaN           NaN
# 11176989         NaN        NaN           NaN

# %%
new_df[(new_df.num_cpf_hash == '0069c06b6016281ff4af4f6b585d89b4efa25c270de9cbf857253db1bd47f3f2')]
# Out:
#           anomes                                       num_cpf_hash  \
# 998356    202104  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 1974201   202105  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 2933003   202106  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 3877163   202107  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 4805704   202108  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 5720012   202109  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 6629330   202110  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 7530663   202111  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 8420477   202112  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 9299136   202201  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 10172815  202202  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 11170176  202203  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
# 12031078  202204  0069c06b6016281ff4af4f6b585d89b4efa25c270de9cb...
#
#           vlr_credito  vlr_saldo  num_atend_atrs  vlr_score  num_produtos  \
# 998356       34348.65    5246.76             NaN      410.0           1.0
# 1974201      34671.39    5220.40             NaN      429.0           1.0
# 2933003      35396.68    5190.45             NaN      568.0           1.0
# 3877163      34782.94    5163.03             NaN      657.0           1.0
# 4805704      36242.87    5135.11             NaN      670.0           1.0
# 5720012      35324.15    5103.63             NaN      475.0           1.0
# 6629330      25577.68    5074.59             NaN      439.0           1.0
# 7530663      28059.39    5042.02             NaN        NaN           1.0
# 8420477      26131.61    5011.87             NaN      519.0           1.0
# 9299136      38040.05    4981.09             NaN      516.0           1.0
# 10172815     39985.18    4940.95             NaN      575.0           1.0
# 11170176     40571.55    4908.88             NaN      575.0           1.0
# 12031078     38947.91    4873.36             NaN      523.0           1.0
#
#           num_atend  qtd_oper  qtd_reclm  qtd_restr vlr_renda cod_rating  \
# 998356          NaN      52.0        NaN        1.0       NaN          A
# 1974201         NaN      35.0        NaN        1.0       NaN          A
# 2933003         NaN      38.0        NaN        NaN       NaN          A
# 3877163         NaN      40.0        NaN        1.0       NaN          A
# 4805704         NaN      52.0        NaN        NaN       NaN          A
# 5720012         NaN      51.0        NaN        2.0       NaN          A
# 6629330         NaN      55.0        NaN        3.0       NaN          A
# 7530663         NaN      30.0        NaN        3.0       NaN          A
# 8420477         NaN      30.0        NaN        1.0       NaN          A
# 9299136         NaN      26.0        NaN        2.0       NaN          A
# 10172815        NaN      24.0        NaN        1.0       NaN          A
# 11170176        NaN      22.0        NaN        1.0   4050,00          A
# 12031078        NaN      23.0        1.0        2.0       NaN          A
#
#           ind_atrito  ind_engaj  ind_novo_cli
# 998356           NaN        NaN           NaN
# 1974201          NaN        NaN           NaN
# 2933003          NaN        NaN           NaN
# 3877163          NaN        NaN           NaN
# 4805704          NaN        NaN           NaN
# 5720012          NaN        NaN           NaN
# 6629330          NaN        NaN           NaN
# 7530663          NaN        NaN           NaN
# 8420477          NaN        NaN           NaN
# 9299136          NaN        NaN           NaN
# 10172815         NaN        NaN           NaN
# 11170176         NaN        NaN           NaN
# 12031078         1.0        NaN           NaN

# %%
new_df[(new_df.num_cpf_hash == '01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4757a05a706707c406d')]
# Out:
#           anomes                                       num_cpf_hash  \
# 992983    202104  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 1968942   202105  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 2927847   202106  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 3872086   202107  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 4800713   202108  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 5715084   202109  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 6624425   202110  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 7525816   202111  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 8415694   202112  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 9294390   202201  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 10168091  202202  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 11164814  202203  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
# 12026448  202204  01cf69537ed0cad6e0a3ecb6f6913cf0f1572ee12f64e4...
#
#           vlr_credito  vlr_saldo  num_atend_atrs  vlr_score  num_produtos  \
# 992983        1843.30     750.69             NaN      159.0           1.0
# 1968942       1843.31     750.69             NaN      164.0           1.0
# 2927847          0.00     750.69             NaN      156.0           NaN
# 3872086          0.00     750.69             NaN        NaN           NaN
# 4800713          0.00     750.69             NaN        NaN           NaN
# 5715084           NaN     750.69             NaN        NaN           NaN
# 6624425           NaN     750.69             NaN        NaN           NaN
# 7525816           NaN     750.69             NaN      308.0           NaN
# 8415694           NaN     750.69             NaN      293.0           NaN
# 9294390           NaN     750.69             NaN      295.0           NaN
# 10168091          NaN     750.69             NaN      291.0           NaN
# 11164814          NaN     750.69             NaN      280.0           NaN
# 12026448          NaN     750.69             NaN      334.0           NaN
#
#           num_atend  qtd_oper  qtd_reclm  qtd_restr vlr_renda cod_rating  \
# 992983          NaN       7.0        NaN        8.0       NaN          H
# 1968942         NaN       7.0        NaN        8.0       NaN          H
# 2927847         NaN       7.0        NaN        8.0       NaN         HH
# 3872086         NaN       7.0        NaN        8.0       NaN         HH
# 4800713         NaN       7.0        NaN        8.0       NaN         HH
# 5715084         NaN       NaN        NaN        8.0       NaN         HH
# 6624425         NaN       NaN        NaN        8.0       NaN         HH
# 7525816         NaN       NaN        NaN        8.0       NaN         HH
# 8415694         NaN       NaN        NaN        8.0       NaN         HH
# 9294390         NaN       NaN        NaN        8.0       NaN         HH
# 10168091        NaN       NaN        NaN        8.0       NaN         HH
# 11164814        NaN       NaN        NaN        8.0   1500,00         HH
# 12026448        NaN       NaN        NaN        8.0       NaN         HH
#
#           ind_atrito  ind_engaj  ind_novo_cli
# 992983           NaN        NaN           NaN
# 1968942          NaN        NaN           NaN
# 2927847          NaN        NaN           NaN
# 3872086          NaN        NaN           NaN
# 4800713          NaN        NaN           NaN
# 5715084          NaN        NaN           NaN
# 6624425          NaN        NaN           NaN
# 7525816          NaN        NaN           NaN
# 8415694          NaN        NaN           NaN
# 9294390          NaN        NaN           NaN
# 10168091         NaN        NaN           NaN
# 11164814         NaN        NaN           NaN
# 12026448         1.0        NaN           NaN

# %% [markdown]
# Os resultados das análises, comparando os três cpfs, foram inconclusivos

# %% [markdown]
# 2. Engajado

# %%
# Coletar o ID do cpf a partir da última safra
new_df[(new_df.anomes == 202111) & (new_df.ind_engaj == 1)].head()
# Out:
#          anomes                                       num_cpf_hash  \
# 6630818  202111  ffffd54b45ec46113523184fc07185a0d5cbfa876a07ba...
# 6630821  202111  ffffbd4a3d42a12e07b1202d68c33d43220c42c8a55160...
# 6630825  202111  ffff4ef886c28af8029c6b7d504942e6c9ef13021e9a35...
# 6630826  202111  ffff4bbb4074d7894174fd94c685edb3fd7fc9b7b1e3c1...
# 6630832  202111  fffe7c6f3755240f56780edde1f91b70de574bf4e6e767...
#
#          vlr_credito  vlr_saldo  num_atend_atrs  vlr_score  num_produtos  \
# 6630818     34004.35    5757.73             NaN      422.0           2.0
# 6630821      6642.56    1400.31             NaN      659.0           2.0
# 6630825     78377.15    5221.45             NaN        NaN           1.0
# 6630826    120997.23    6619.70             NaN      337.0           2.0
# 6630832      9733.81    1752.80             NaN      592.0           1.0
#
#          num_atend  qtd_oper  qtd_reclm  qtd_restr vlr_renda cod_rating  \
# 6630818        NaN      12.0        NaN        3.0       NaN          A
# 6630821        NaN      37.0        NaN        NaN       NaN          A
# 6630825        NaN      14.0        NaN        NaN       NaN          A
# 6630826        NaN      23.0        NaN        1.0       NaN          A
# 6630832        NaN       9.0        NaN        NaN       NaN          A
#
#          ind_atrito  ind_engaj  ind_novo_cli
# 6630818         NaN        1.0           NaN
# 6630821         NaN        1.0           NaN
# 6630825         NaN        1.0           NaN
# 6630826         NaN        1.0           NaN
# 6630832         NaN        1.0           NaN

# %%
# Coletar o número do cpf completo pelo ID
new_df.loc[7532135	,'num_cpf_hash']
# Out:
# '00003671431c71ae1a84ec138b63c7a6e465f9616af5ea9ab0c2572da9c2f204'

# %%
# Visualização de cada mês de um cpf
new_df[(new_df.num_cpf_hash == '00003671431c71ae1a84ec138b63c7a6e465f9616af5ea9ab0c2572da9c2f204')]
# Out:
#           anomes                                       num_cpf_hash  \
# 999994    202104  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 1975804   202105  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 2934578   202106  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 3878703   202107  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 4807215   202108  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 5721500   202109  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 6630815   202110  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 7532135   202111  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 8421935   202112  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 9300585   202201  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 10174253  202202  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 11171810  202203  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
# 12032491  202204  00003671431c71ae1a84ec138b63c7a6e465f9616af5ea...
#
#           vlr_credito  vlr_saldo  num_atend_atrs  vlr_score  num_produtos  \
# 999994        2352.13    1443.31             NaN      372.0           1.0
# 1975804       2371.52    1443.67             NaN      325.0           1.0
# 2934578       2410.22    1443.67             NaN      325.0           1.0
# 3878703       3521.21    1443.67             NaN      287.0           1.0
# 4807215       3877.10    1443.67             NaN      311.0           1.0
# 5721500       4004.44    1443.67             NaN      302.0           1.0
# 6630815       4156.74    1443.67             NaN      308.0           1.0
# 7532135       4295.58    1443.67             NaN      329.0           1.0
# 8421935       3811.21    1363.47             NaN      379.0           1.0
# 9300585           NaN        NaN             NaN      398.0           NaN
# 10174253          NaN        NaN             NaN      383.0           NaN
# 11171810          NaN        NaN             NaN      339.0           NaN
# 12032491          NaN        NaN             NaN      373.0           NaN
#
#           num_atend  qtd_oper  qtd_reclm  qtd_restr vlr_renda cod_rating  \
# 999994          NaN       9.0        NaN        1.0       NaN          E
# 1975804         NaN       8.0        NaN        2.0       NaN          F
# 2934578         NaN       6.0        NaN        2.0       NaN          G
# 3878703         NaN       6.0        NaN        3.0       NaN          H
# 4807215         NaN       5.0        NaN        3.0       NaN          H
# 5721500         NaN       5.0        NaN        3.0       NaN          H
# 6630815         NaN       5.0        NaN        3.0       NaN          H
# 7532135         NaN       5.0        NaN        3.0       NaN          H
# 8421935         NaN       4.0        NaN        3.0       NaN          H
# 9300585         NaN       NaN        NaN        2.0       NaN        NaN
# 10174253        NaN       NaN        NaN        2.0       NaN        NaN
# 11171810        NaN       NaN        NaN        2.0   1550,00        NaN
# 12032491        NaN       NaN        NaN        2.0       NaN        NaN
#
#           ind_atrito  ind_engaj  ind_novo_cli
# 999994           NaN        1.0           NaN
# 1975804          NaN        1.0           NaN
# 2934578          NaN        NaN           NaN
# 3878703          NaN        NaN           NaN
# 4807215          NaN        NaN           NaN
# 5721500          NaN        NaN           NaN
# 6630815          NaN        NaN           NaN
# 7532135          NaN        1.0           NaN
# 8421935          NaN        NaN           NaN
# 9300585          NaN        NaN           1.0
# 10174253         NaN        NaN           1.0
# 11171810         NaN        NaN           1.0
# 12032491         NaN        NaN           1.0

# %% [markdown]
# Os resultados apresentados foram inconclusivos, de acordo com as hipóteses testadas
